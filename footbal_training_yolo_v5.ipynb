# %%
# %pip install roboflow
# Out:
# ...
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/f7/d2/6bb7779b2191715541f6d68c4b9e4d905097047464f397b99ec11d57ce85/roboflow-1.1.45-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for idna==3.7 from https://files.pythonhosted.org/packages/e5/3e/741d8c82801c347547f8a2a06aa57dbb1992be9e948df2ea0eda2c8b79e8/idna-3.7-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for opencv-python-headless==4.10.0.84 from https://files.pythonhosted.org/packages/26/d0/22f68eb23eea053a31655960f133c0be9726c6a881547e6e9e7e2a946c4f/opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for filetype from https://files.pythonhosted.org/packages/18/79/1b8fa1bb3568781e84c9200f951c735f3f157429f44be0495da55894d620/filetype-1.2.0-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
# ...

# %% [markdown]
# ## Get the dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="DHJtiRtdm0ktmpO3McQQ")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.102, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov8:: 100%|██████████| 1338/1338 [00:01<00:00, 958.89it/s]

# %% [markdown]
# Now we have created a folder football-players-detection-1, inside which there is training, test, validation data, but it should be moved into a folder inside the football-players-detection-1, with same name, to avoid making the code crash

# %%
import shutil

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train')
shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test')
shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
dataset.location
# Out:
# 'c:\\Users\\hemes\\OneDrive - Indiana University\\Projects\\FootBall_Analysis\\training\\football-players-detection-1'

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
# !yolo task=detect mode=train model=yolov5x.pt data="c:\\Users\\hemes\\OneDrive - Indiana University\\Projects\\FootBall_Analysis\\training\\football-players-detection-1/data.yaml" epochs=100 imgsz=640 device=0 workers=0
